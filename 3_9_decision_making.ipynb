# %% [markdown]
# #If statements & If-else & If-elif & Nested Statements

# %% [markdown]
# ![dm1.png](data:image/png;base64,...)

# %% [markdown]
# #If Statements

# %% [markdown]
# ![dm2.png](data:image/png;base64,...)

# %%
if test expression:
  statement(s)

# %%
# If the number is positive, we print an appropriate message
#case1: positive number
#case2: negative number
#case3: zero

num = float(input('Enter the integer number:'))
if num > 0:
    print(num, "is a positive number.")

if num < 0:
    print(num, "is a negative number.")

print("This is always printed.")
# Out:
# Enter the integer number:5
# 5.0 is a positive number.

# %% [markdown]
# #If else statment

# %% [markdown]
# ![dm3.png](data:image/png;base64,...)

# %%
if test expression:
    Body of if
else:
    Body of else

# %%
# If the number is positive, we print an appropriate message
#case1: positive number
#case2: negative number
#case3: zero

num = float(input('Enter the integer number:'))
if num > 0:
    print(num, "is a positive number.")
else:
    print(num, "is a negative number.")
print("This is always printed.")
# Out:
# Enter the integer number:-5
# -5.0 is a negative number.
# This is always printed.

# %% [markdown]
# #if...elif...else Statement

# %% [markdown]
# ![dm4.png](data:image/png;base64,...)

# %%
if test expression:
    Body of if
elif test expression:
    Body of elif
else: 
    Body of else

# %%
# If the number is positive, we print an appropriate message
#case1: positive number
#case2: negative number
#case3: zero

num = float(input('Enter the integer number:'))
if num > 0:
    print(num, "is a positive number.")
elif num == 0:
    print(num, "is not positive or negative, it's zero!")
else:
    print(num, "is a negative number.")
# Out:
# Enter the integer number:0
# 0.0 is not positive or negative, it's zero!

# %% [markdown]
# #Nested If statement

# %% [markdown]
# ![dm5.png](data:image/png;base64,...)

# %%
'''In this program, we input a number
check if the number is positive or
negative or zero and display
an appropriate message
This time we use nested if statement'''

num = float(input("Enter a number: "))
if num >= 0:
    if num == 0:
        print("Zero")
    else:
        print("Positive number")
else:
    print("Negative number")
# Out:
# Enter a number: -5
# Negative number

# %% [markdown]
# #Multiple conditions with statements

# %% [markdown]
# Condition for leap year: A leap year is exactly divisible by 4 except for century years (years ending with 00). The century year is a leap year only if it is perfectly divisible by 400

# %%
# Python program to check if year is a leap year or not

year = int(input('Enter the year: you need to find for leap year:'))

# divided by 100 means century year (ending with 00)
# century year divided by 400 is leap year
if (year % 400 == 0) and (year % 100 == 0):
    print("{0} is a leap year".format(year))

# not divided by 100 means not a century year
# year divided by 4 is a leap year
elif (year % 4 ==0) and (year % 100 != 0):
    print("{0} is a leap year".format(year))

# if not divided by both 400 (century year) and 4 (not century year)
# year is not leap year
else:
    print("{0} is not a leap year".format(year))
# Out:
# Enter the year: you need to find for leap year:2200
# 2200 is not a leap year

# %% [markdown]
# #Assignment

# %%
#Check if a Number is Odd or Even
a=int(input("enter a no"))
if a%2==0:
  print("the number is even")
else :
  print("the number is odd")
# Out:
# enter a no3
# the number is odd

# %%
#Find the Largest Among Three Numbers
a=int(input("enter number1"))
b=int(input("enter number2"))
c=int(input("enter number3"))
if a>b and a>c:
  print("number 1 is greater")
elif b>a and b>c:
  print("number 2 is greater")
else:
  print("number 3 is greater")
# Out:
# enter number112
# enter number2238
# enter number3980
# number 3 is greater
